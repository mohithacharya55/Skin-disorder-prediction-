# %% [markdown]
# # Skin Disorder

# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading dataset

# %%
data = pd.read_csv('skin_disorder.csv')
data
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# ...

# %% [markdown]
# ### Basic checks

# %%
data.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  \
# 0                           1                  0  ...
# ...

# %%
data.tail()
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 361                  0                   0                         0
# 362                  0                   0                         0
# 363                  2                   0                         2
# 364                  3                   0                         2
# 365                  0                   0                         0
#
#      knee_and_elbow_involvement  scalp_involvement  ...  \
# 361                           0                  0  ...
# ...

# %%
data.shape
# Out:
# (366, 35)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   erythema                                  366 non-null    int64
#  1   scaling                                   366 non-null    int64
#  2   definite_borders                          366 non-null    int64
#  3   itching                                   366 non-null    int64
#  4   koebner_phenomenon                        366 non-null    int64
#  5   polygonal_papules                         366 non-null    int64
#  6   follicular_papules                        366 non-null    int64
#  7   oral_mucosal_involvement                  366 non-null    int64
#  8   knee_and_elbow_involvement                366 non-null    int64
#  9   scalp_involvement                         366 non-null    int64
# ...

# %%
data.isnull().sum()   # there are no null values
# Out:
# erythema                                    0
# scaling                                     0
# definite_borders                            0
# itching                                     0
# koebner_phenomenon                          0
# polygonal_papules                           0
# follicular_papules                          0
# oral_mucosal_involvement                    0
# knee_and_elbow_involvement                  0
# scalp_involvement                           0
# family_history                              0
# melanin_incontinence                        0
# eosinophils_in_the_infiltrate               0
# PNL_infiltrate                              0
# fibrosis_of_the_papillary_dermis            0
# exocytosis                                  0
# acanthosis                                  0
# hyperkeratosis                              0
# parakeratosis                               0
# clubbing_of_the_rete_ridges                 0
# ...

# %%
data.describe()
# Out:
#          erythema     scaling  definite_borders     itching  \
# count  366.000000  366.000000        366.000000  366.000000
# mean     2.068306    1.795082          1.549180    1.366120
# std      0.664753    0.701527          0.907525    1.138299
# min      0.000000    0.000000          0.000000    0.000000
# 25%      2.000000    1.000000          1.000000    0.000000
# 50%      2.000000    2.000000          2.000000    1.000000
# 75%      2.000000    2.000000          2.000000    2.000000
# max      3.000000    3.000000          3.000000    3.000000
#
#        koebner_phenomenon  polygonal_papules  follicular_papules  \
# count          366.000000         366.000000          366.000000
# mean             0.633880           0.448087            0.166667
# std              0.908016           0.957327            0.570588
# min              0.000000           0.000000            0.000000
# 25%              0.000000           0.000000            0.000000
# ...

# %%
data.describe(include ='O')
# Out:
#         Age
# count   366
# unique   61
# top      40
# freq     17

# %%
data.columns
# Out:
# Index(['erythema', 'scaling', 'definite_borders', 'itching',
#        'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
#        'oral_mucosal_involvement', 'knee_and_elbow_involvement',
#        'scalp_involvement', 'family_history', 'melanin_incontinence',
#        'eosinophils_in_the_infiltrate', 'PNL_infiltrate',
#        'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis',
#        'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges',
#        'elongation_of_the_rete_ridges',
#        'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule',
#        'munro_microabcess', 'focal_hypergranulosis',
#        'disappearance_of_the_granular_layer',
#        'vacuolisation_and_damage_of_basal_layer', 'spongiosis',
#        'saw-tooth_appearance_of_retes', 'follicular_horn_plug',
#        'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate',
#        'band-like_infiltrate', 'Age', 'class'],
#       dtype='object')

# %%
data =data.rename({'saw-tooth_appearance_of_retes' : 'saw_tooth_appearance_of_retes', 'band-like_infiltrate' :'band_like_infiltrate'}, axis =1 )

# %%
data.columns
# Out:
# Index(['erythema', 'scaling', 'definite_borders', 'itching',
#        'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
#        'oral_mucosal_involvement', 'knee_and_elbow_involvement',
#        'scalp_involvement', 'family_history', 'melanin_incontinence',
#        'eosinophils_in_the_infiltrate', 'PNL_infiltrate',
#        'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis',
#        'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges',
#        'elongation_of_the_rete_ridges',
#        'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule',
#        'munro_microabcess', 'focal_hypergranulosis',
#        'disappearance_of_the_granular_layer',
#        'vacuolisation_and_damage_of_basal_layer', 'spongiosis',
#        'saw_tooth_appearance_of_retes', 'follicular_horn_plug',
#        'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate',
#        'band_like_infiltrate', 'Age', 'class'],
#       dtype='object')

# %%
data.family_history.value_counts() # the family history feature has the value 1 if any of these diseases has been observed in the family, and 0 otherwise.
# Out:
# family_history
# 0    320
# 1     46
# Name: count, dtype: int64

# %%
"""
Every other feature (clinical and histopathological) was given a degree in the range of 0 to 3. 
Here, 0 indicates that the feature was not present, 3 indicates the largest amount possible, and 1, 2 indicate the relative intermediate values.
"""
# Out:
# '\nEvery other feature (clinical and histopathological) was given a degree in the range of 0 to 3. \nHere, 0 indicates that the feature was not present, 3 indicates the largest amount possible, and 1, 2 indicate the relative intermediate values.\n'

# %%
data.erythema.value_counts()
# Out:
# erythema
# 2    215
# 3     90
# 1     57
# 0      4
# Name: count, dtype: int64

# %%
data.scaling.value_counts()
# Out:
# scaling
# 2    195
# 1    111
# 3     52
# 0      8
# Name: count, dtype: int64

# %%
data.definite_borders.value_counts()
# Out:
# definite_borders
# 2    168
# 1     93
# 0     59
# 3     46
# Name: count, dtype: int64

# %%
data.itching.value_counts()
# Out:
# itching
# 0    118
# 2    100
# 3     76
# 1     72
# Name: count, dtype: int64

# %%
data.koebner_phenomenon.value_counts()
# Out:
# koebner_phenomenon
# 0    224
# 1     70
# 2     54
# 3     18
# Name: count, dtype: int64

# %%
data.polygonal_papules.value_counts()
# Out:
# polygonal_papules
# 0    297
# 2     41
# 3     27
# 1      1
# Name: count, dtype: int64

# %%
data.follicular_papules.value_counts()
# Out:
# follicular_papules
# 0    333
# 2     16
# 1     11
# 3      6
# Name: count, dtype: int64

# %%
data.oral_mucosal_involvement.value_counts()
# Out:
# oral_mucosal_involvement
# 0    299
# 2     45
# 3     13
# 1      9
# Name: count, dtype: int64

# %%
data.knee_and_elbow_involvement.value_counts()
# Out:
# knee_and_elbow_involvement
# 0    251
# 2     64
# 1     28
# 3     23
# Name: count, dtype: int64

# %%
data.scalp_involvement.value_counts()
# Out:
# scalp_involvement
# 0    264
# 2     56
# 1     30
# 3     16
# Name: count, dtype: int64

# %%
data.melanin_incontinence.value_counts()
# Out:
# melanin_incontinence
# 0    296
# 2     46
# 3     16
# 1      8
# Name: count, dtype: int64

# %%
data.eosinophils_in_the_infiltrate.value_counts()
# Out:
# eosinophils_in_the_infiltrate
# 0    324
# 1     33
# 2      9
# Name: count, dtype: int64

# %%
data.PNL_infiltrate.value_counts()
# Out:
# PNL_infiltrate
# 0    235
# 1     69
# 2     55
# 3      7
# Name: count, dtype: int64

# %%
data.fibrosis_of_the_papillary_dermis.value_counts()
# Out:
# fibrosis_of_the_papillary_dermis
# 0    312
# 3     23
# 2     23
# 1      8
# Name: count, dtype: int64

# %%
data.exocytosis.value_counts()
# Out:
# exocytosis
# 2    129
# 0    118
# 3     62
# 1     57
# Name: count, dtype: int64

# %%
data.acanthosis.value_counts()
# Out:
# acanthosis
# 2    210
# 3     75
# 1     71
# 0     10
# Name: count, dtype: int64

# %%
data.hyperkeratosis.value_counts()
# Out:
# hyperkeratosis
# 0    227
# 1     90
# 2     44
# 3      5
# Name: count, dtype: int64

# %%
data.parakeratosis.value_counts()
# Out:
# parakeratosis
# 2    132
# 1    118
# 0     86
# 3     30
# Name: count, dtype: int64

# %%
data.clubbing_of_the_rete_ridges.value_counts()
# Out:
# clubbing_of_the_rete_ridges
# 0    252
# 2     61
# 3     34
# 1     19
# Name: count, dtype: int64

# %%
data.elongation_of_the_rete_ridges.value_counts()
# Out:
# elongation_of_the_rete_ridges
# 0    198
# 2     95
# 3     50
# 1     23
# Name: count, dtype: int64

# %%
data.thinning_of_the_suprapapillary_epidermis.value_counts()
# Out:
# thinning_of_the_suprapapillary_epidermis
# 0    256
# 2     60
# 3     31
# 1     19
# Name: count, dtype: int64

# %%
data.spongiform_pustule.value_counts()
# Out:
# spongiform_pustule
# 0    296
# 1     38
# 2     26
# 3      6
# Name: count, dtype: int64

# %%
data.munro_microabcess.value_counts()
# Out:
# munro_microabcess
# 0    286
# 1     37
# 2     33
# 3     10
# Name: count, dtype: int64

# %%
data.focal_hypergranulosis.value_counts()
# Out:
# focal_hypergranulosis
# 0    295
# 2     43
# 3     15
# 1     13
# Name: count, dtype: int64

# %%
data.disappearance_of_the_granular_layer.value_counts()
# Out:
# disappearance_of_the_granular_layer
# 0    273
# 2     49
# 1     30
# 3     14
# Name: count, dtype: int64

# %%
data.vacuolisation_and_damage_of_basal_layer.value_counts()
# Out:
# vacuolisation_and_damage_of_basal_layer
# 0    294
# 2     43
# 3     26
# 1      3
# Name: count, dtype: int64

# %%
data.spongiosis.value_counts()
# Out:
# spongiosis
# 0    199
# 2     96
# 3     43
# 1     28
# Name: count, dtype: int64

# %%
data.saw_tooth_appearance_of_retes.value_counts()
# Out:
# saw_tooth_appearance_of_retes
# 0    294
# 2     40
# 3     27
# 1      5
# Name: count, dtype: int64

# %%
data.follicular_horn_plug.value_counts()
# Out:
# follicular_horn_plug
# 0    344
# 1     10
# 2      8
# 3      4
# Name: count, dtype: int64

# %%
data.perifollicular_parakeratosis.value_counts()
# Out:
# perifollicular_parakeratosis
# 0    345
# 2     13
# 1      4
# 3      4
# Name: count, dtype: int64

# %%
data.inflammatory_monoluclear_inflitrate.value_counts()
# Out:
# inflammatory_monoluclear_inflitrate
# 2    206
# 1     85
# 3     62
# 0     13
# Name: count, dtype: int64

# %%
data.band_like_infiltrate.value_counts()
# Out:
# band_like_infiltrate
# 0    289
# 3     52
# 2     22
# 1      3
# Name: count, dtype: int64

# %%
data['class'].value_counts()
# Out:
# class
# 1    112
# 3     72
# 2     61
# 5     52
# 4     49
# 6     20
# Name: count, dtype: int64

# %%
data.Age.dtype   # age is has object dtype
# Out:
# dtype('O')

# %%
data.Age.unique()  # there is ? and 0  in age column
# Out:
# array(['55', '8', '26', '40', '45', '41', '18', '57', '22', '30', '20',
#        '21', '10', '65', '38', '23', '17', '51', '42', '44', '33', '43',
#        '50', '34', '?', '15', '46', '62', '35', '48', '12', '52', '60',
#        '32', '19', '29', '25', '36', '13', '27', '31', '28', '64', '39',
#        '47', '16', '0', '7', '70', '37', '61', '67', '56', '53', '24',
#        '58', '49', '63', '68', '9', '75'], dtype=object)

# %%
data['Age'] = data['Age'].replace('?', None)

# %%
data.Age.unique()
# Out:
# array(['55', '8', '26', '40', '45', '41', '18', '57', '22', '30', '20',
#        '21', '10', '65', '38', '23', '17', '51', '42', '44', '33', '43',
#        '50', '34', None, '15', '46', '62', '35', '48', '12', '52', '60',
#        '32', '19', '29', '25', '36', '13', '27', '31', '28', '64', '39',
#        '47', '16', '0', '7', '70', '37', '61', '67', '56', '53', '24',
#        '58', '49', '63', '68', '9', '75'], dtype=object)

# %%
data['Age'] = pd.to_numeric(data['Age'], errors='coerce')

# %%
data.Age.unique()
# Out:
# array([55.,  8., 26., 40., 45., 41., 18., 57., 22., 30., 20., 21., 10.,
#        65., 38., 23., 17., 51., 42., 44., 33., 43., 50., 34., nan, 15.,
#        46., 62., 35., 48., 12., 52., 60., 32., 19., 29., 25., 36., 13.,
#        27., 31., 28., 64., 39., 47., 16.,  0.,  7., 70., 37., 61., 67.,
#        56., 53., 24., 58., 49., 63., 68.,  9., 75.])

# %%
median_value = data['Age'].median()

data['Age'] = data['Age'].fillna(median_value)
data['Age'] = data['Age'].replace(0, median_value)

# %%
data.Age.unique()
# Out:
# array([55.,  8., 26., 40., 45., 41., 18., 57., 22., 30., 20., 21., 10.,
#        65., 38., 23., 17., 51., 42., 44., 33., 43., 50., 34., 35., 15.,
#        46., 62., 48., 12., 52., 60., 32., 19., 29., 25., 36., 13., 27.,
#        31., 28., 64., 39., 47., 16.,  7., 70., 37., 61., 67., 56., 53.,
#        24., 58., 49., 63., 68.,  9., 75.])

# %%
data.Age.dtype
# Out:
# dtype('float64')

# %%
data['Age'] = data['Age'].astype('int64')

# %%
data.Age.dtype
# Out:
# dtype('int64')

# %%
data[data.duplicated()]   #no duplicate rows present
# Out:
# Empty DataFrame
# Columns: [erythema, scaling, definite_borders, itching, koebner_phenomenon, polygonal_papules, follicular_papules, oral_mucosal_involvement, knee_and_elbow_involvement, scalp_involvement, family_history, melanin_incontinence, eosinophils_in_the_infiltrate, PNL_infiltrate, fibrosis_of_the_papillary_dermis, exocytosis, acanthosis, hyperkeratosis, parakeratosis, clubbing_of_the_rete_ridges, elongation_of_the_rete_ridges, thinning_of_the_suprapapillary_epidermis, spongiform_pustule, munro_microabcess, focal_hypergranulosis, disappearance_of_the_granular_layer, vacuolisation_and_damage_of_basal_layer, spongiosis, saw_tooth_appearance_of_retes, follicular_horn_plug, perifollicular_parakeratosis, inflammatory_monoluclear_inflitrate, band_like_infiltrate, Age, class]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# ### EDA

# %%
# univariate analysis

# %%
columns = ['erythema', 'scaling', 'definite_borders', 'itching',
           'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
           'oral_mucosal_involvement', 'knee_and_elbow_involvement',
           'scalp_involvement', 'family_history', 'melanin_incontinence',
           'eosinophils_in_the_infiltrate', 'PNL_infiltrate',
           'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis',
           'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges',
           'elongation_of_the_rete_ridges',
           'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule',
           'munro_microabcess', 'focal_hypergranulosis',
           'disappearance_of_the_granular_layer',
           'vacuolisation_and_damage_of_basal_layer', 'spongiosis',
           'saw_tooth_appearance_of_retes', 'follicular_horn_plug',
           'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate',
           'band_like_infiltrate', 'class']


num_cols = 3  
num_rows = -(-len(columns) // num_cols)  
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, num_rows * 4))

axes = axes.flatten()

for i, col in enumerate(columns):
    sns.countplot(data=data, x=col, ax=axes[i], palette='viridis')
    axes[i].set_title(f'Countplot of {col}', fontsize=10)
    axes[i].tick_params(axis='x', rotation=45)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Count')


for j in range(len(columns), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
sns.histplot(data['Age'],kde =True)
plt.show()

# %%
# bivariate analysis

# %%
features = ['erythema','scaling', 'itching', 'family_history']

num_features = len(features)
num_cols = 2 
num_rows = -(-num_features // num_cols)  
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, num_rows * 5))

axes = axes.flatten()
for i, feature in enumerate(features):
    sns.boxplot(x=feature, y='Age', data=data, ax=axes[i], palette='viridis')
    axes[i].set_title(f'{feature} vs Age', fontsize=12)
    axes[i].set_xlabel(feature, fontsize=10)
    axes[i].set_ylabel('Age', fontsize=10)

for j in range(len(features), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
sns.boxplot(data['Age'])    # no outliers
plt.show()

# %%
data['class'] = data['class'].astype(str)

columns = ['erythema', 'scaling', 'definite_borders', 'itching',
           'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
           'oral_mucosal_involvement', 'knee_and_elbow_involvement',
           'scalp_involvement', 'family_history', 'melanin_incontinence',
           'eosinophils_in_the_infiltrate', 'PNL_infiltrate',
           'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis',
           'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges',
           'elongation_of_the_rete_ridges', 'thinning_of_the_suprapapillary_epidermis',
           'spongiform_pustule', 'munro_microabcess', 'focal_hypergranulosis',
           'disappearance_of_the_granular_layer', 'vacuolisation_and_damage_of_basal_layer',
           'spongiosis', 'saw_tooth_appearance_of_retes', 'follicular_horn_plug',
           'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate',
           'band_like_infiltrate']

num_cols = 3
num_rows = -(-len(columns) // num_cols)  
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, num_rows * 4))

axes = axes.flatten()
for i, col in enumerate(columns):
    sns.countplot(data=data, x=col, hue='class', ax=axes[i], palette='viridis')
    axes[i].set_title(f'Countplot of {col}', fontsize=10)
    axes[i].tick_params(axis='x', rotation=45)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Count')

for j in range(len(columns), len(axes)):
    fig.delaxes(axes[j])


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (12,10)),
sns.heatmap(data.corr(), cmap='coolwarm')
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['erythema', 'scaling', 'definite_borders', 'itching',
#        'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
#        'oral_mucosal_involvement', 'knee_and_elbow_involvement',
#        'scalp_involvement', 'family_history', 'melanin_incontinence',
#        'eosinophils_in_the_infiltrate', 'PNL_infiltrate',
#        'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis',
#        'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges',
#        'elongation_of_the_rete_ridges',
#        'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule',
#        'munro_microabcess', 'focal_hypergranulosis',
#        'disappearance_of_the_granular_layer',
#        'vacuolisation_and_damage_of_basal_layer', 'spongiosis',
#        'saw_tooth_appearance_of_retes', 'follicular_horn_plug',
#        'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate',
#        'band_like_infiltrate', 'Age', 'class'],
#       dtype='object')

# %%
data= data.drop(['perifollicular_parakeratosis'], axis =1) # because it has high correlation with input column

# %% [markdown]
# ### Feature Importance

# %%
from sklearn.ensemble import RandomForestClassifier

X = data.drop(columns=['class'])  
y = data['class']  

rf = RandomForestClassifier()
rf.fit(X, y)


feature_importances = rf.feature_importances_


feature_importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': feature_importances
})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)


plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Feature Importance using Random Forest')
plt.show()


print(feature_importance_df)
# Out:
#                                      Feature  Importance
# 19               clubbing_of_the_rete_ridges    0.090067
# 14          fibrosis_of_the_papillary_dermis    0.082860
# 21  thinning_of_the_suprapapillary_epidermis    0.078000
# 20             elongation_of_the_rete_ridges    0.071094
# 4                         koebner_phenomenon    0.059138
# 31                      band_like_infiltrate    0.046034
# 27                                spongiosis    0.044318
# 8                 knee_and_elbow_involvement    0.042049
# 11                      melanin_incontinence    0.039843
# 26   vacuolisation_and_damage_of_basal_layer    0.033426
# 5                          polygonal_papules    0.033392
# 13                            PNL_infiltrate    0.031960
# 28             saw_tooth_appearance_of_retes    0.031926
# 32                                       Age    0.031276
# 15                                exocytosis    0.028414
# ...

# %% [markdown]
# ### Splitting the data

# %%
x = data.drop(['class'], axis=1)
y = data['class']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize the KNeighborsClassifier
logistic_regression = LogisticRegression()

# Train the model
logistic_regression.fit(x_train, y_train)

# Make predictions
y_pred = logistic_regression.predict(x_test)

# Evaluate the model
print("logistic regression")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# logistic regression
# Accuracy: 0.9864864864864865
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        31
#            2       0.90      1.00      0.95         9
#            3       1.00      1.00      1.00        13
#            4       1.00      0.88      0.93         8
#            5       1.00      1.00      1.00        10
#            6       1.00      1.00      1.00         3
#
#     accuracy                           0.99        74
#    macro avg       0.98      0.98      0.98        74
# weighted avg       0.99      0.99      0.99        74
#
#
# Confusion Matrix:
#  [[31  0  0  0  0  0]
#  [ 0  9  0  0  0  0]
#  [ 0  0 13  0  0  0]
#  [ 0  1  0  7  0  0]
#  [ 0  0  0  0 10  0]
#  [ 0  0  0  0  0  3]]

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize the KNeighborsClassifier
knn_classifier = KNeighborsClassifier()

# Train the model
knn_classifier.fit(x_train, y_train)

# Make predictions
y_pred_knn = knn_classifier.predict(x_test)

# Evaluate the model
print("K-Nearest Neighbors (KNN)")
print("Accuracy:", accuracy_score(y_test, y_pred_knn))
print("\nClassification Report:\n", classification_report(y_test, y_pred_knn))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_knn))
# Out:
# K-Nearest Neighbors (KNN)
# Accuracy: 0.8243243243243243
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      0.94      0.97        31
#            2       0.55      0.67      0.60         9
#            3       1.00      1.00      1.00        13
#            4       0.44      0.50      0.47         8
#            5       0.80      0.80      0.80        10
#            6       0.50      0.33      0.40         3
#
#     accuracy                           0.82        74
#    macro avg       0.71      0.71      0.71        74
# weighted avg       0.84      0.82      0.83        74
#
#
# Confusion Matrix:
#  [[29  1  0  0  0  1]
#  [ 0  6  0  3  0  0]
#  [ 0  0 13  0  0  0]
#  [ 0  2  0  4  2  0]
#  [ 0  1  0  1  8  0]
#  [ 0  1  0  1  0  1]]

# %% [markdown]
# ### Navie bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize the GaussianNB model
nb_classifier = GaussianNB()

# Train the model
nb_classifier.fit(x_train, y_train)

# Make predictions
y_pred_nb = nb_classifier.predict(x_test)

# Evaluate the model
print("Naive Bayes (GaussianNB)")
print("Accuracy:", accuracy_score(y_test, y_pred_nb))
print("\nClassification Report:\n", classification_report(y_test, y_pred_nb))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_nb))
# Out:
# Naive Bayes (GaussianNB)
# Accuracy: 0.9054054054054054
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        31
#            2       0.75      0.33      0.46         9
#            3       1.00      1.00      1.00        13
#            4       0.67      1.00      0.80         8
#            5       0.82      0.90      0.86        10
#            6       1.00      1.00      1.00         3
#
#     accuracy                           0.91        74
#    macro avg       0.87      0.87      0.85        74
# weighted avg       0.91      0.91      0.89        74
#
#
# Confusion Matrix:
#  [[31  0  0  0  0  0]
#  [ 0  3  0  4  2  0]
#  [ 0  0 13  0  0  0]
#  [ 0  0  0  8  0  0]
#  [ 0  1  0  0  9  0]
#  [ 0  0  0  0  0  3]]

# %% [markdown]
# ### SVC

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

svc_model = SVC(probability =True)
svc_model.fit(x_train, y_train)

# Make predictions
y_pred = svc_model.predict(x_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7297297297297297
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.94      1.00      0.97        31
#            2       0.33      1.00      0.50         9
#            3       1.00      1.00      1.00        13
#            4       0.00      0.00      0.00         8
#            5       0.00      0.00      0.00        10
#            6       1.00      0.33      0.50         3
#
#     accuracy                           0.73        74
#    macro avg       0.55      0.56      0.49        74
# weighted avg       0.65      0.73      0.66        74

# %% [markdown]
# ### Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

dt_classifier = DecisionTreeClassifier(random_state=42)

# Train the model
dt_classifier.fit(x_train, y_train)

# Make predictions
y_pred_dt = dt_classifier.predict(x_test)

# Evaluate the model
print("Decision Tree Classifier")
print("Accuracy:", accuracy_score(y_test, y_pred_dt))
print("\nClassification Report:\n", classification_report(y_test, y_pred_dt))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_dt))
# Out:
# Decision Tree Classifier
# Accuracy: 0.9864864864864865
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.97      1.00      0.98        31
#            2       1.00      1.00      1.00         9
#            3       1.00      1.00      1.00        13
#            4       1.00      1.00      1.00         8
#            5       1.00      0.90      0.95        10
#            6       1.00      1.00      1.00         3
#
#     accuracy                           0.99        74
#    macro avg       0.99      0.98      0.99        74
# weighted avg       0.99      0.99      0.99        74
#
#
# Confusion Matrix:
#  [[31  0  0  0  0  0]
#  [ 0  9  0  0  0  0]
#  [ 0  0 13  0  0  0]
#  [ 0  0  0  8  0  0]
#  [ 1  0  0  0  9  0]
#  [ 0  0  0  0  0  3]]

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

rf_classifier = RandomForestClassifier()

#Train the model
rf_classifier.fit(x_train, y_train)

# Make Predictions
y_pred = rf_classifier.predict(x_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        31
#            2       1.00      1.00      1.00         9
#            3       1.00      1.00      1.00        13
#            4       1.00      1.00      1.00         8
#            5       1.00      1.00      1.00        10
#            6       1.00      1.00      1.00         3
#
#     accuracy                           1.00        74
#    macro avg       1.00      1.00      1.00        74
# weighted avg       1.00      1.00      1.00        74
#
#
# Confusion Matrix:
#  [[31  0  0  0  0  0]
#  [ 0  9  0  0  0  0]
#  [ 0  0 13  0  0  0]
#  [ 0  0  0  8  0  0]
#  [ 0  0  0  0 10  0]
#  [ 0  0  0  0  0  3]]

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

gb_classifier = GradientBoostingClassifier(random_state=42)

# Train the model
gb_classifier.fit(x_train, y_train)

# Make predictions
y_pred_gb = gb_classifier.predict(x_test)

# Evaluate the model
print("Gradient Boosting Classifier")
print("Accuracy:", accuracy_score(y_test, y_pred_gb))
print("\nClassification Report:\n", classification_report(y_test, y_pred_gb))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_gb))
# Out:
# Gradient Boosting Classifier
# Accuracy: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        31
#            2       1.00      1.00      1.00         9
#            3       1.00      1.00      1.00        13
#            4       1.00      1.00      1.00         8
#            5       1.00      1.00      1.00        10
#            6       1.00      1.00      1.00         3
#
#     accuracy                           1.00        74
#    macro avg       1.00      1.00      1.00        74
# weighted avg       1.00      1.00      1.00        74
#
#
# Confusion Matrix:
#  [[31  0  0  0  0  0]
#  [ 0  9  0  0  0  0]
#  [ 0  0 13  0  0  0]
#  [ 0  0  0  8  0  0]
#  [ 0  0  0  0 10  0]
#  [ 0  0  0  0  0  3]]

# %% [markdown]
# # Results

# %% [markdown]
# ### Out of all the following classification algorithm Gradient boosting is giving highest accuracy of 100%

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

gb_classifier = GradientBoostingClassifier(random_state=42)

# Train the model
gb_classifier.fit(x_train, y_train)

# Make predictions
y_pred_gb = gb_classifier.predict(x_test)

# Evaluate the model
print("Gradient Boosting Classifier")
print("Accuracy:", accuracy_score(y_test, y_pred_gb))
print("\nClassification Report:\n", classification_report(y_test, y_pred_gb))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_gb))
# Out:
# Gradient Boosting Classifier
# Accuracy: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        31
#            2       1.00      1.00      1.00         9
#            3       1.00      1.00      1.00        13
#            4       1.00      1.00      1.00         8
#            5       1.00      1.00      1.00        10
#            6       1.00      1.00      1.00         3
#
#     accuracy                           1.00        74
#    macro avg       1.00      1.00      1.00        74
# weighted avg       1.00      1.00      1.00        74
#
#
# Confusion Matrix:
#  [[31  0  0  0  0  0]
#  [ 0  9  0  0  0  0]
#  [ 0  0 13  0  0  0]
#  [ 0  0  0  8  0  0]
#  [ 0  0  0  0 10  0]
#  [ 0  0  0  0  0  3]]

# %%
input_columns = [
    'erythema', 'scaling', 'definite_borders', 'itching', 'koebner_phenomenon',
    'polygonal_papules', 'follicular_papules', 'oral_mucosal_involvement',
    'knee_and_elbow_involvement', 'scalp_involvement', 'family_history',
    'melanin_incontinence', 'eosinophils_in_the_infiltrate', 'PNL_infiltrate',
    'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis', 'hyperkeratosis',
    'parakeratosis', 'clubbing_of_the_rete_ridges', 'elongation_of_the_rete_ridges',
    'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule',
    'munro_microabcess', 'focal_hypergranulosis', 'disappearance_of_the_granular_layer',
    'vacuolisation_and_damage_of_basal_layer', 'spongiosis', 'saw_tooth_appearance_of_retes',
    'follicular_horn_plug', 'inflammatory_monoluclear_inflitrate',
    'band_like_infiltrate', 'Age'
]

print("\nEnter the following values for prediction:")
custom_input = []

for col in input_columns:
    try:
        value = float(input(f"Enter value for {col}: "))
        custom_input.append(value)
    except ValueError:
        print(f"Invalid input for {col}. Please enter a numeric value.")
        break

custom_input = [custom_input]

try:
    custom_prediction = gb_classifier.predict(custom_input)
    predicted_class = custom_prediction[0]
    print(f"\nThe predicted class is: {predicted_class} (Condition Class: {predicted_class})")
except Exception as e:
    print(f"\nAn error occurred during prediction: {e}")
# Out:
# Enter the following values for prediction:
# Enter value for erythema:  2
# Enter value for scaling:  2
# Enter value for definite_borders:  0
# Enter value for itching:  3
# Enter value for koebner_phenomenon:  0
# Enter value for polygonal_papules:  0
# Enter value for follicular_papules:  0
# Enter value for oral_mucosal_involvement:  0
# Enter value for knee_and_elbow_involvement:  1
# Enter value for scalp_involvement:  0
# Enter value for family_history:  0
# Enter value for melanin_incontinence:  0
# Enter value for eosinophils_in_the_infiltrate:  0
# Enter value for PNL_infiltrate:  0
# Enter value for fibrosis_of_the_papillary_dermis:  0
# Enter value for exocytosis:  3
# Enter value for acanthosis:  2
# Enter value for hyperkeratosis:  0
# Enter value for parakeratosis:  0
# Enter value for clubbing_of_the_rete_ridges:  0
# Enter value for elongation_of_the_rete_ridges:  0
# Enter value for thinning_of_the_suprapapillary_epidermis:  0
# ...

# %% [markdown]
# # Model Comparison Report

# %% [markdown]
# Objective
# The objective of this study is to build and evaluate machine learning models to predict or classify skin disorders based on the given dataset.
#
# Dataset Overview
# Dataset size: 366 x 35
# Target Variable: class
#
# Data Preprocessing Steps
# renaming column name
# replacing ?, 0 value present in age column
#
# Exploratory Data Analysis
# Univariate
# Bivariate
# correlation
#
# Feature engineering
# Droping column which are least correlated with target column
#
# Splitting the dataset into training and testing sets
# Applying different algorithm
# Fitting and predict the model
# Evaluating the result

# %%
AllAccuracyOfTheModel = {
    'Logistic Regression' : 93.64,
    'KNN':83.78,
    'naive bayes' : 90.54,
    'support vector classifier' : 74.32,
    'Decision Tree':98.64,
    'Random Forest':98.64,    
    'gradient boosting classifier':100
    
}
keys = AllAccuracyOfTheModel.keys()
values = AllAccuracyOfTheModel.values()

plt.figure(figsize=(8, 6))
bars = plt.bar(keys, values, color='lightblue', edgecolor='black')  

plt.xlabel('Accuracy of all the models')
plt.ylabel('% Age of the accuracy of the models')
plt.title('Comparison of models')
plt.xticks(rotation=45, fontsize=7)

for bar, value in zip(bars, values):
    plt.text(bar.get_x() + bar.get_width() / 2, value + 0.2, f'{value}%', ha='center', va='bottom')

plt.show()

# %% [markdown]
# # Report on Challenges Faced

# %% [markdown]
# Issue 1:
# Identified invalid values (? and 0) and replaced them with NaN for uniformity.
# Converted the Age column to a numeric type.
# Computed the median of the valid age values.
# Filled the NaN values with the calculated median using fillna().
#
# Issue 2:
# Used the rename() method in Python to rename columns to more descriptive and concise names.
#
# Issue 3:
# Computed the correlation matrix to identify highly correlated features.
# Dropped one of each pair of highly correlated columns to retain only the most informative features.
#
# Issue 4:
# Trained a baseline model (e.g., Random Forest, Gradient Boosting) to calculate feature importance scores.
# Visualized feature importance using bar plots for better interpretation.
